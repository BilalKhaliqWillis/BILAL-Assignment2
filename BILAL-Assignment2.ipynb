# %% [markdown]
# <a href="https://colab.research.google.com/github/BilalKhaliqWillis/BILAL-Assignment2/blob/main/BILAL-Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git config --global user.name "bilalkhaliqwillis"
# !git config --global user.email "khan.bilal.khan327@gmaail.com"

# %%
import getpass
token = getpass.getpass('Enter GitHub PAT: ')
# Out:
# Enter GitHub PAT: ··········

# %%
# !git clone https://github.com/bilalkhaliqwillis/BILAL-Assignment2>.git
# Out:
# Cloning into 'BILAL-Assignment2'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !ls BILAL-Assignment2
# Out:
# README.md
